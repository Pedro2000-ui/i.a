# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 37s 81ms/step - loss: 0.3595 - accuracy: 0.8919 - val_loss: 0.0821 - val_accuracy: 0.9772
# Epoch 2/15
# 422/422 [==============================] - 30s 71ms/step - loss: 0.1109 - accuracy: 0.9661 - val_loss: 0.0562 - val_accuracy: 0.9835
# Epoch 3/15
# 422/422 [==============================] - 30s 70ms/step - loss: 0.0834 - accuracy: 0.9741 - val_loss: 0.0460 - val_accuracy: 0.9863
# Epoch 4/15
# 422/422 [==============================] - 31s 74ms/step - loss: 0.0704 - accuracy: 0.9785 - val_loss: 0.0409 - val_accuracy: 0.9908
# Epoch 5/15
# 422/422 [==============================] - 30s 71ms/step - loss: 0.0619 - accuracy: 0.9806 - val_loss: 0.0361 - val_accuracy: 0.9888
# Epoch 6/15
# 422/422 [==============================] - 31s 73ms/step - loss: 0.0552 - accuracy: 0.9826 - val_loss: 0.0351 - val_accuracy: 0.9902
# Epoch 7/15
# 422/422 [==============================] - 30s 72ms/step - loss: 0.0512 - accuracy: 0.9839 - val_loss: 0.0325 - val_accuracy: 0.9905
# Epoch 8/15
# 422/422 [==============================] - 31s 73ms/step - loss: 0.0470 - accuracy: 0.9855 - val_loss: 0.0332 - val_accuracy: 0.9898
# Epoch 9/15
# 422/422 [==============================] - 30s 70ms/step - loss: 0.0431 - accuracy: 0.9856 - val_loss: 0.0371 - val_accuracy: 0.9893
# Epoch 10/15
# 422/422 [==============================] - 30s 72ms/step - loss: 0.0407 - accuracy: 0.9866 - val_loss: 0.0374 - val_accuracy: 0.9895
# Epoch 11/15
# 422/422 [==============================] - 30s 71ms/step - loss: 0.0400 - accuracy: 0.9870 - val_loss: 0.0326 - val_accuracy: 0.9910
# Epoch 12/15
# 422/422 [==============================] - 30s 71ms/step - loss: 0.0371 - accuracy: 0.9882 - val_loss: 0.0296 - val_accuracy: 0.9918
# Epoch 13/15
# 422/422 [==============================] - 30s 70ms/step - loss: 0.0359 - accuracy: 0.9882 - val_loss: 0.0293 - val_accuracy: 0.9913
# Epoch 14/15
# 422/422 [==============================] - 30s 70ms/step - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.0315 - val_accuracy: 0.9913
# Epoch 15/15
# 422/422 [==============================] - 29s 69ms/step - loss: 0.0336 - accuracy: 0.9893 - val_loss: 0.0306 - val_accuracy: 0.9915

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.02569660358130932
# Test accuracy: 0.9907000064849854

# %%
cv2_imshow(x_test[0]*255)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-693bf1565d7a> in <module>
# ----> 1 cv2_imshow(x_test[0]*255)
#
# NameError: name 'cv2_imshow' is not defined

# %%
y_test[0]

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('2.png', cv2.IMREAD_UNCHANGED)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#gray = cv2.bitwise_not(gray)
resized = cv2.resize(gray, (28, 28))
cv2_imshow(resized)

# %%
y_prob = model.predict(np.array([resized/255.0]))
classes_x=np.argmax(y_prob,axis=1)
classes_x
